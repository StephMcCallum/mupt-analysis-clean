# %%
from cmeutils.structure import (
    bond_distribution,
    angle_distribution,
    dihedral_distribution,
)
from cmeutils.plotting import get_histogram

import gsd.hoomd
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

import os

# %% [markdown]
# # Bond Distributions

# %%
fig = plt.figure()
chains = 1
bond = "AA"
nbins=100
weight_dist = np.zeros(nbins)
adist = bond_distribution(
    gsd_file = ("cg_p3ht_50mer.gsd"),
    A_name=bond[0],
    B_name=bond[1],
    histogram=True,
    normalize=True,
    start=200,
    bins=nbins
)
smooth = signal.savgol_filter(adist[:,1], window_length=7, polyorder=1)
weight_dist += smooth

plt.plot(adist[:,0], weight_dist/7, markersize=0)

plt.xlabel("$L$[$\sigma$]")
plt.ylabel("P($L$)")
plt.title("50-mer Single Chain CG P3HT")
fig.tight_layout()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/877339794.py:20: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel("$L$[$\sigma$]")

# %%
fig = plt.figure()
chains = 1
bond = "AB"
nbins=100
weight_dist = np.zeros(nbins)
adist = bond_distribution(
    gsd_file = ("cg_p3ht_50mer.gsd"),
    A_name=bond[0],
    B_name=bond[1],
    histogram=True,
    normalize=True,
    start=200,
    bins=nbins
)
smooth = signal.savgol_filter(adist[:,1], window_length=7, polyorder=1)
weight_dist += smooth

plt.plot(adist[:,0], weight_dist/7, markersize=0)

plt.xlabel("$L$[$\sigma$]")
plt.ylabel("P($L$)")
plt.title("50-mer Single Chain CG P3HT")
fig.tight_layout()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/466984428.py:20: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel("$L$[$\sigma$]")

# %%
fig = plt.figure()
chains = 1
bond = "BB"
nbins=100
weight_dist = np.zeros(nbins)
adist = bond_distribution(
    gsd_file = ("cg_p3ht_50mer.gsd"),
    A_name=bond[0],
    B_name=bond[1],
    histogram=True,
    normalize=True,
    start=200,
    bins=nbins
)
smooth = signal.savgol_filter(adist[:,1], window_length=7, polyorder=1)
weight_dist += smooth

plt.plot(adist[:,0], weight_dist/7, markersize=0)

plt.xlabel("$L$[$\sigma$]")
plt.ylabel("P($L$)")
plt.title("50-mer Single Chain CG P3HT")
fig.tight_layout()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/260623087.py:20: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel("$L$[$\sigma$]")

# %% [markdown]
# # Angle Distributions

# %%
fig = plt.figure()
chains = 1
angle = "AAA"
nbins = 200
weight_dist = np.zeros(nbins)
adist = angle_distribution(
    gsd_file = ("cg_p3ht_50mer.gsd"),
    A_name=angle[0],
    B_name=angle[1],
    C_name=angle[2],
    histogram=True,
    normalize=True,
    start =0,
    bins=nbins
    )
smooth = signal.savgol_filter(adist[:,1], window_length=7, polyorder=1)
weight_dist += smooth

plt.plot(adist[:,0], weight_dist/7, markersize=0)
    
plt.xlabel("$\Theta$ [rad]")
plt.ylabel("P($\Theta$)")
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\T'
# <>:22: SyntaxWarning: invalid escape sequence '\T'
# <>:21: SyntaxWarning: invalid escape sequence '\T'
# <>:22: SyntaxWarning: invalid escape sequence '\T'
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/903240832.py:21: SyntaxWarning: invalid escape sequence '\T'
#   plt.xlabel("$\Theta$ [rad]")
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/903240832.py:22: SyntaxWarning: invalid escape sequence '\T'
#   plt.ylabel("P($\Theta$)")
# Text(0, 0.5, 'P($\\Theta$)')

# %%
fig = plt.figure()
chains = 1
angle = "BAA"
nbins = 200
weight_dist = np.zeros(nbins)
adist = angle_distribution(
    gsd_file = ("cg_p3ht_50mer.gsd"),
    A_name=angle[0],
    B_name=angle[1],
    C_name=angle[2],
    histogram=True,
    normalize=True,
    start =0,
    bins=nbins
    )
smooth = signal.savgol_filter(adist[:,1], window_length=7, polyorder=1)
weight_dist += smooth

plt.plot(adist[:,0], weight_dist/7, markersize=0)
    
plt.xlabel("$\Theta$ [rad]")
plt.ylabel("P($\Theta$)")
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\T'
# <>:22: SyntaxWarning: invalid escape sequence '\T'
# <>:21: SyntaxWarning: invalid escape sequence '\T'
# <>:22: SyntaxWarning: invalid escape sequence '\T'
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/3177530302.py:21: SyntaxWarning: invalid escape sequence '\T'
#   plt.xlabel("$\Theta$ [rad]")
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/3177530302.py:22: SyntaxWarning: invalid escape sequence '\T'
#   plt.ylabel("P($\Theta$)")
# Text(0, 0.5, 'P($\\Theta$)')

# %% [markdown]
# # Torsion Distributions

# %%
fig = plt.figure()
chains = 1
angle = "AAAA"
nbins = 200
weight_dist = np.zeros(nbins)
adist = dihedral_distribution(
    gsd_file = ("cg_p3ht_50mer.gsd"),
    A_name=angle[0],
    B_name=angle[1],
    C_name=angle[2],
    D_name=angle[3],
    histogram=True,
    normalize=True,
    start =0,
    bins=nbins
    )
smooth = signal.savgol_filter(adist[:,1], window_length=7, polyorder=1)
weight_dist += smooth

plt.plot(adist[:,0], weight_dist/7, markersize=0)
    
plt.xlabel("$\Phi$[rad]")
plt.ylabel("P($\Phi$)")
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\P'
# <>:23: SyntaxWarning: invalid escape sequence '\P'
# <>:22: SyntaxWarning: invalid escape sequence '\P'
# <>:23: SyntaxWarning: invalid escape sequence '\P'
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/1479448107.py:22: SyntaxWarning: invalid escape sequence '\P'
#   plt.xlabel("$\Phi$[rad]")
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/1479448107.py:23: SyntaxWarning: invalid escape sequence '\P'
#   plt.ylabel("P($\Phi$)")
# Text(0, 0.5, 'P($\\Phi$)')

# %%
fig = plt.figure()
chains = 1
angle = "BAAB"
nbins = 200
weight_dist = np.zeros(nbins)
adist = dihedral_distribution(
    gsd_file = ("cg_p3ht_50mer.gsd"),
    A_name=angle[0],
    B_name=angle[1],
    C_name=angle[2],
    D_name=angle[3],
    histogram=True,
    normalize=True,
    start =0,
    bins=nbins
    )
smooth = signal.savgol_filter(adist[:,1], window_length=7, polyorder=1)
weight_dist += smooth

plt.plot(adist[:,0], weight_dist/7, markersize=0)
    
plt.xlabel("$\Phi$[rad]")
plt.ylabel("P($\Phi$)")
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\P'
# <>:23: SyntaxWarning: invalid escape sequence '\P'
# <>:22: SyntaxWarning: invalid escape sequence '\P'
# <>:23: SyntaxWarning: invalid escape sequence '\P'
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/3430623509.py:22: SyntaxWarning: invalid escape sequence '\P'
#   plt.xlabel("$\Phi$[rad]")
# /var/folders/jr/8265_v612wxg_7hntt0sy_780000gn/T/ipykernel_89691/3430623509.py:23: SyntaxWarning: invalid escape sequence '\P'
#   plt.ylabel("P($\Phi$)")
# Text(0, 0.5, 'P($\\Phi$)')
