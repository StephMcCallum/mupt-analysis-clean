# %% [markdown]
# <a href="https://colab.research.google.com/github/erjank/mupt-analysis/blob/main/MSD_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Please navigate to block (4) and (5) to see the Final code with comments.
# #### Let's gradually walk through the problems and code!

# %% [markdown]
# #### Part - 1

# %% [markdown]
# #### import the files
# #### 1) .dump (contains trajectories)
# #### 2) .txt (containes timesteps)

# %%
# Get dependencies that aren't included in colab, plus example files for analysis
# !pip install MDAnalysis
# !wget https://raw.githubusercontent.com/MuPT-hub/mupt-analysis/refs/heads/main/production_1ns.dump
# !wget https://raw.githubusercontent.com/MuPT-hub/mupt-analysis/refs/heads/main/python.txt
# Out:
# --2025-06-11 18:06:11--  https://raw.githubusercontent.com/MuPT-hub/mupt-analysis/refs/heads/main/python.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 115 [text/plain]
# Saving to: ‘python.txt’
#
# python.txt          100%[===================>]     115  --.-KB/s    in 0s
#
# 2025-06-11 18:06:11 (6.06 MB/s) - ‘python.txt’ saved [115/115]

# %%
import MDAnalysis as mda
import matplotlib.pyplot as plt
import numpy as np
import MDAnalysis.analysis.msd as msd
u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")
python_times = np.loadtxt('python.txt')
#
# Out:
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/topology/LAMMPSParser.py:651: UserWarning: Guessed all Masses to 1.0
#   warnings.warn("Guessed all Masses to 1.0")
# /usr/local/lib/python3.11/dist-packages/MDAnalysis/coordinates/LAMMPS.py:751: UserWarning: Reader has no dt information, set to 1.0 ps
#   ts.data["time"] = step_num * ts.dt

# %% [markdown]
# #### I will the values of the .txt file multiple (between linearly and non-linear/exponentially increased ts) before each block of code and run the codes to compare...

# %% [markdown]
# #### 1) Calculate MSD. No time averaging only average over all the particles! timesteps are the usual exponential trend we follow i.e., 2^0 to 2^20

# %%
import MDAnalysis as mda
import matplotlib.pyplot as plt
import numpy as np
import MDAnalysis.analysis.msd as msd
u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")
python_times = np.loadtxt('python.txt')
# Select all atoms
all_atoms = u.select_atoms("all")
n_atoms = len(all_atoms)
n_frames = len(u.trajectory)
# Store initial positions (frame 0)
u.trajectory[0]
initial_positions = all_atoms.positions.copy()

# Prepare array to store MSD per frame
msd_per_frame = np.zeros(n_frames)

# Loop over frames
for i, ts in enumerate(u.trajectory):
    current_positions = all_atoms.positions
    displacements = current_positions - initial_positions
    squared_displacements = np.sum(displacements**2, axis=1)  # sum over x, y, z
    msd = np.mean(squared_displacements)  # average over all atoms
    msd_per_frame[i] = msd
    print(f"Frame {i}: MSD = {msd}")

# Plot
plt.figure(figsize=(8, 6))
plt.plot(python_times, msd_per_frame, marker='o', linestyle='-')
plt.xlabel('Time (from python.txt)')
plt.ylabel('Mean Squared Displacement (MSD)')
plt.title('MSD vs Time')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Frame 0: MSD = 0.0
# Frame 1: MSD = 7.567644206574187e-05
# Frame 2: MSD = 0.0006711921305395663
# Frame 3: MSD = 0.0034164325334131718
# Frame 4: MSD = 0.012431675568223
# Frame 5: MSD = 9.529627799987793
# Frame 6: MSD = 15.158470153808594
# Frame 7: MSD = 23.198976516723633
# Frame 8: MSD = 30.702102661132812
# Frame 9: MSD = 39.68592834472656
# Frame 10: MSD = 51.815765380859375
# Frame 11: MSD = 64.29840087890625
# Frame 12: MSD = 79.07508087158203
# Frame 13: MSD = 95.05611419677734
# Frame 14: MSD = 115.84335327148438
# Frame 15: MSD = 138.80897521972656
# Frame 16: MSD = 165.20802307128906
# Frame 17: MSD = 198.88772583007812
# Frame 18: MSD = 232.73460388183594
# Frame 19: MSD = 268.996826171875
# Frame 20: MSD = 335.84283447265625

# %% [markdown]
# #### 2) Now with Time averaging. Changing the .txt as linearly dumped 1 2 3 4 ..... 21

# %%
import MDAnalysis as mda
import matplotlib.pyplot as plt
import numpy as np
import MDAnalysis.analysis.msd as msd
u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")
python_times = np.loadtxt('python_linear.txt')
import numpy as np

# Select all atoms
all_atoms = u.select_atoms("all")
n_atoms = len(all_atoms)
n_frames = len(u.trajectory)

# Preload all positions into a (n_frames, n_atoms, 3) array
positions = np.zeros((n_frames, n_atoms, 3))
for frame_idx, ts in enumerate(u.trajectory):
    positions[frame_idx] = all_atoms.positions

# Prepare array to store MSD vs. time lag (Δt)
max_dt = n_frames - 1  # max possible lag
msd_vs_dt = np.zeros(max_dt)

# Loop over time lags Δt = 1 to max_dt
for dt in range(1, max_dt + 1):
    msd_sum = 0.0
    count = 0

    # Loop over all valid start frames
    for start in range(n_frames - dt):
        pos_start = positions[start]
        pos_end = positions[start + dt]

        # Calculate displacement for all atoms
        disp = pos_end - pos_start  # shape (n_atoms, 3)
        squared_disp = np.sum(disp ** 2, axis=1)  # shape (n_atoms,)

        # Average over atoms
        msd_frame = np.mean(squared_disp)
        msd_sum += msd_frame
        count += 1

    # Average over all start points
    msd_vs_dt[dt - 1] = msd_sum / count
    print(f"Δt {dt}: MSD = {msd_vs_dt[dt - 1]}")

def shift_array_right_with_zero(arr):
    shifted = np.zeros(len(arr) + 1, dtype=arr.dtype)
    shifted[1:] = arr
    return shifted
# print(shift_array_right_with_zero(msd_vs_dt))
msd_vs_dt = shift_array_right_with_zero(msd_vs_dt)

plt.figure(figsize=(8, 6))
plt.plot(python_times, msd_vs_dt, marker='o', linestyle='-')
plt.xlabel('Time (from python.txt)')
plt.ylabel('Mean Squared Displacement (MSD)')
plt.title('MSD vs Time')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Δt 1: MSD = 77.84795168948702
# Δt 2: MSD = 91.28136499721225
# Δt 3: MSD = 100.16714904784327
# Δt 4: MSD = 108.50426102164515
# Δt 5: MSD = 115.95459365517337
# Δt 6: MSD = 123.2225137586285
# Δt 7: MSD = 131.66137450674026
# Δt 8: MSD = 140.01342542785522
# Δt 9: MSD = 148.9154453683269
# Δt 10: MSD = 158.9512833983638
# Δt 11: MSD = 169.51377544593112
# Δt 12: MSD = 181.2876291731876
# Δt 13: MSD = 194.06853782920817
# Δt 14: MSD = 208.1029101366353
# Δt 15: MSD = 223.4742138746855
# Δt 16: MSD = 240.34210457992407
# Δt 17: MSD = 259.1198865030255
# Δt 18: MSD = 279.193535757145
# Δt 19: MSD = 302.4206399988626
# Δt 20: MSD = 335.84280119424255

# %% [markdown]
# #### 3) MDA claims to do the time averaging too so let's check! (linearly dumped 1 2 3 4 ..... 21)

# %%
import MDAnalysis as mda
import matplotlib.pyplot as plt
import numpy as np
import MDAnalysis.analysis.msd as msd
u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")
python_times = np.loadtxt('python_linear.txt')

u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")

MSD = msd.EinsteinMSD(u, select='all', msd_type='xyz', fft=True)
MSD.run()

msd_MDA =  MSD.results.timeseries

print(msd_MDA)

fig = plt.figure()
ax = plt.axes()

ax.plot(python_times, msd_MDA, ls="-", label=r'3D random walk')
# Out:
# 100%|██████████| 60000/60000 [00:05<00:00, 10561.15it/s]
# [-1.07568970e-11  7.78479517e+01  9.12813650e+01  1.00167149e+02
#   1.08504261e+02  1.15954594e+02  1.23222514e+02  1.31661375e+02
#   1.40013425e+02  1.48915445e+02  1.58951283e+02  1.69513775e+02
#   1.81287629e+02  1.94068538e+02  2.08102910e+02  2.23474214e+02
#   2.40342105e+02  2.59119887e+02  2.79193536e+02  3.02420640e+02
#   3.35842801e+02]

# %% [markdown]
# #### Okay so the last two are Matched! By doing so far we have reached two conclusions:
# #### i. If there is a linear dump msd package from MDA can be used and we have figured the behind the scenes code with the formula.
# #### ii. If the system is non-linear we can skip the time averaging part and take the first frame as reference and assign an MSD value to all the other frames.

# %% [markdown]
# #### 3.2) Let's again use the msd package from MDA. This time let's just update the python.txt and compare the plots with the first block of code (non-time averaging). Updating the .txt to 2^0 to 2^20

# %%
import MDAnalysis as mda
import matplotlib.pyplot as plt
import numpy as np
import MDAnalysis.analysis.msd as msd
u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")
python_times = np.loadtxt('python.txt')

u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")

MSD = msd.EinsteinMSD(u, select='all', msd_type='xyz', fft=True)
MSD.run()

msd_MDA =  MSD.results.timeseries

print(msd_MDA)

fig = plt.figure()
ax = plt.axes()

ax.plot(python_times, msd_MDA, ls="-", label=r'3D random walk')
# Out:
# 100%|██████████| 60000/60000 [00:05<00:00, 10696.47it/s]
# [-1.07568970e-11  7.78479517e+01  9.12813650e+01  1.00167149e+02
#   1.08504261e+02  1.15954594e+02  1.23222514e+02  1.31661375e+02
#   1.40013425e+02  1.48915445e+02  1.58951283e+02  1.69513775e+02
#   1.81287629e+02  1.94068538e+02  2.08102910e+02  2.23474214e+02
#   2.40342105e+02  2.59119887e+02  2.79193536e+02  3.02420640e+02
#   3.35842801e+02]

# %% [markdown]
# #### So, we can clearly see that from block 3.2 msd in MDA doesn't work for non-linear timesteps. Basically, it is considering every file to be linear dumped and doing the time averaging. The solution so far is to not do the time averaging for a non-linear dumped file.

# %% [markdown]
# #### This is good but we can do better!
# #### For a non-linearly dumped file there can be two more delta_t (difference in their absolute timesteps) between any two pairs of frames without repetation. We can average the MSD values of such frame pairs with same delta_t!

# %% [markdown]
# #### Part - 2

# %% [markdown]
# #### 4) The approach is the same as block (2) that go to each frame calculate the msds from each frame and update dictionary with key (delta_t) : value (msd). For pairs with same delta_t  average the msd and for unique delta_t just append in the dictionary. Show and plot the key (x axis) vs value (y axis)

# %%
import matplotlib.pyplot as plt
from collections import defaultdict
import MDAnalysis as mda
import matplotlib.pyplot as plt
import numpy as np
import MDAnalysis.analysis.msd as msd
u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")
python_times = np.loadtxt('python.txt')

# Load universe
u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")

# Load actual times (shape: n_frames,)
times = np.loadtxt('python.txt')
n_frames = len(times)

# Select all atoms
all_atoms = u.select_atoms("all")
n_atoms = len(all_atoms)

# Preload positions (shape: n_frames, n_atoms, 3)
positions = np.zeros((n_frames, n_atoms, 3))
for frame_idx, ts in enumerate(u.trajectory):
    positions[frame_idx] = all_atoms.positions

# Dictionary to collect MSDs: {Δt: [msd1, msd2, ...]}
msd_dict = defaultdict(list)

# Loop over all frame pairs (i < j)
for i in range(n_frames):
    for j in range(i + 1, n_frames):
        delta_t = times[j] - times[i]

        # Compute displacement and squared displacement
        disp = positions[j] - positions[i]  # shape (n_atoms, 3)
        squared_disp = np.sum(disp ** 2, axis=1)  # shape (n_atoms,)
        msd = np.mean(squared_disp)  # average over atoms

        # Store MSD under corresponding Δt
        msd_dict[delta_t].append(msd)

print(msd_dict)
msd_dict[0] = [0]
# Prepare averaged results
delta_t_values = []
avg_msds = []

for delta_t in sorted(msd_dict.keys()):
    msd_list = msd_dict[delta_t]
    avg_msd = np.mean(msd_list)
    delta_t_values.append(delta_t)
    avg_msds.append(avg_msd)
    print(f"Δt = {delta_t}: Averaged MSD = {avg_msd} (from {len(msd_list)} pairs)")

# Plot Δt vs averaged MSD
plt.figure(figsize=(8, 5))
plt.plot(delta_t_values, avg_msds, marker='o', linestyle='-', label='Averaged MSD')

plt.xlabel('Δt (Time Difference)')
plt.ylabel('Mean Squared Displacement (MSD)')
plt.title('MSD Averaged Over Frame Pairs with Same Δt')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# defaultdict(<class 'list'>, {1.0: [7.567643921399091e-05], 3.0: [0.0006711921641563701], 7.0: [0.0034164327871623753], 15.0: [0.012431675144152965], 31.0: [9.529627627822155], 63.0: [15.158470625154514], 127.0: [23.198975843973113], 255.0: [30.702104041633415], 511.0: [39.685930721940814], 1023.0: [51.81576843253431], 2047.0: [64.29840190573968], 4095.0: [79.07508475484535], 8191.0: [95.0561195452338], 16383.0: [115.84334776265332], 32767.0: [138.8089833987945], 65535.0: [165.20803198843214], 131071.0: [198.8877409309397], 262143.0: [232.73461269452594], 524287.0: [268.9968443646768], 1048575.0: [335.84280119424255], 2.0: [0.0003010483342465401], 6.0: [0.0025656259044513716], 14.0: [0.011181908940227003], 30.0: [9.529808290536062], 62.0: [15.158977168059968], 126.0: [23.199660636605618], 254.0: [30.70256620998786], 510.0: [39.68684729387202], 1022.0: [51.816659110028965], 2046.0: [64.29958717407878], 4094.0: [79.07646287403166], 8190.0: [95.05691656152716], 16382.0: [115.8444636769963], 32766.0: [138.80978457190727], 65534.0: [165.209326059722], 131070.0: [198.8891240609642], 262142.0: [232.73598400765007], 524286.0: [268.99810322258725], 1048574.0: [335.8444356330485], 4.0: [0.0011812128882260973], 12.0: [0.008751948518137457], 28.0: [9.530578573399412], 60.0: [15.160428420627987], 124.0: [23.201359749806645], 252.0: [30.70388223012308], 508.0: [39.68913900853409], 1020.0: [51.81873009825116], 2044.0: [64.30217066505429], 4092.0: [79.0792116951201], 8188.0: [95.0586318471605], 16380.0: [115.84681872223021], 32764.0: [138.81145265630792], 65532.0: [165.21200440639748], 131068.0: [198.89208178986917], 262140.0: [232.73874023244977], 524284.0: [269.0007189627239], 1048572.0: [335.84789135432186], 8.0: [0.004357233602991862], 24.0: [9.533641002612157], 56.0: [15.164856714781138], 120.0: [23.205664242507694], 248.0: [30.70783284917266], 504.0: [39.69503796070986], 1016.0: [51.82351295304266], 2040.0: [64.30764576387135], 4088.0: [79.0846188282073], 8184.0: [95.06224977404133], 16376.0: [115.85158365140158], 32760.0: [138.8145400262058], 65528.0: [165.21748180956425], 131064.0: [198.89847873007443], 262136.0: [232.74432618900195], 524280.0: [269.0060177377771], 1048568.0: [335.8551021107883], 16.0: [9.543333733783664], 48.0: [15.17734442516213], 112.0: [23.216520613257945], 240.0: [30.71894080045508], 496.0: [39.70825215308573], 1008.0: [51.83312577751332], 2032.0: [64.31839593300761], 4080.0: [79.09636476589019], 8176.0: [95.0703795753964], 16368.0: [115.85999522354626], 32752.0: [138.81921029593568], 65520.0: [165.2289176158489], 131056.0: [198.91094224850616], 262128.0: [232.75702127523112], 524272.0: [269.01614463366377], 1048560.0: [335.8686088799973], 32.0: [8.909475600211127], 96.0: [20.476540385422243], 224.0: [29.73568260537573], 480.0: [37.84412065298033], 992.0: [51.007472554264005], 2016.0: [64.08164145732026], 4064.0: [79.61092595254237], 8160.0: [96.07529507293124], 16352.0: [116.1453616118024], 32736.0: [139.32947865853333], 65504.0: [165.24795441208641], 131040.0: [199.13948025737383], 262112.0: [233.75737895526706], 524256.0: [269.2736712071331], 1048544.0: [336.17442117706173], 64.0: [18.009000566625506], 192.0: [28.63409883782932], 448.0: [37.44200568194917], 960.0: [51.26944474867361], 1984.0: [64.32869887817648], 4032.0: [79.70539809428068], 8128.0: [96.46608153410426], 16320.0: [116.07066118887714], 32704.0: [139.53694210194084], 65472.0: [165.43714775006828], 131008.0: [198.8720590139899], 262080.0: [233.07300398776408], 524224.0: [269.3780992129194], 1048512.0: [335.9260630030505], 128.0: [22.78526855092501], 384.0: [36.05976862016476], 896.0: [50.52932277882123], 1920.0: [63.23241846159734], 3968.0: [77.58434323879888], 8064.0: [94.83921412765278], 16256.0: [115.09371358732456], 32640.0: [138.77086026920705], 65408.0: [164.9173708198413], 130944.0: [199.0693117863434], 262016.0: [231.90319528303516], 524160.0: [269.4258243020933], 1048448.0: [335.5723645288706], 256.0: [32.19839134443004], 768.0: [48.140080 ...
# Δt = 0: Averaged MSD = 0.0 (from 1 pairs)
# Δt = 1.0: Averaged MSD = 7.567643921399091e-05 (from 1 pairs)
# Δt = 2.0: Averaged MSD = 0.0003010483342465401 (from 1 pairs)
# Δt = 3.0: Averaged MSD = 0.0006711921641563701 (from 1 pairs)
# Δt = 4.0: Averaged MSD = 0.0011812128882260973 (from 1 pairs)
# Δt = 6.0: Averaged MSD = 0.0025656259044513716 (from 1 pairs)
# Δt = 7.0: Averaged MSD = 0.0034164327871623753 (from 1 pairs)
# Δt = 8.0: Averaged MSD = 0.004357233602991862 (from 1 pairs)
# Δt = 12.0: Averaged MSD = 0.008751948518137457 (from 1 pairs)
# Δt = 14.0: Averaged MSD = 0.011181908940227003 (from 1 pairs)
# Δt = 15.0: Averaged MSD = 0.012431675144152965 (from 1 pairs)
# Δt = 16.0: Averaged MSD = 9.543333733783664 (from 1 pairs)
# Δt = 24.0: Averaged MSD = 9.533641002612157 (from 1 pairs)
# Δt = 28.0: Averaged MSD = 9.530578573399412 (from 1 pairs)
# Δt = 30.0: Averaged MSD = 9.529808290536062 (from 1 pairs)
# Δt = 31.0: Averaged MSD = 9.529627627822155 (from 1 pairs)
# Δt = 32.0: Averaged MSD = 8.909475600211127 (from 1 pairs)
# Δt = 48.0: Averaged MSD = 15.17734442516213 (from 1 pairs)
# Δt = 56.0: Averaged MSD = 15.164856714781138 (from 1 pairs)
# Δt = 60.0: Averaged MSD = 15.160428420627987 (from 1 pairs)
# Δt = 62.0: Averaged MSD = 15.158977168059968 (from 1 pairs)
# Δt = 63.0: Averaged MSD = 15.158470625154514 (from 1 pairs)
# Δt = 64.0: Averaged MSD = 18.009000566625506 (from 1 pairs)
# Δt = 96.0: Averaged MSD = 20.476540385422243 (from 1 pairs)
# Δt = 112.0: Averaged MSD = 23.216520613257945 (from 1 pairs)
# Δt = 120.0: Averaged MSD = 23.205664242507694 (from 1 pairs)
# Δt = 124.0: Averaged MSD = 23.201359749806645 (from 1 pairs)
# Δt = 126.0: Averaged MSD = 23.199660636605618 (from 1 pairs)
# Δt = 127.0: Averaged MSD = 23.198975843973113 (from 1 pairs)
# Δt = 128.0: Averaged MSD = 22.78526855092501 (from 1 pairs)
# Δt = 192.0: Averaged MSD = 28.63409883782932 (from 1 pairs)
# Δt = 224.0: Averaged MSD = 29.73568260537573 (from 1 pairs)
# Δt = 240.0: Averaged MSD = 30.71894080045508 (from 1 pairs)
# Δt = 248.0: Averaged MSD = 30.70783284917266 (from 1 pairs)
# Δt = 252.0: Averaged MSD = 30.70388223012308 (from 1 pairs)
# Δt = 254.0: Averaged MSD = 30.70256620998786 (from 1 pairs)
# Δt = 255.0: Averaged MSD = 30.702104041633415 (from 1 pairs)
# Δt = 256.0: Averaged MSD = 32.19839134443004 (from 1 pairs)
# Δt = 384.0: Averaged MSD = 36.05976862016476 (from 1 pairs)
# Δt = 448.0: Averaged MSD = 37.44200568194917 (from 1 pairs)
# Δt = 480.0: Averaged MSD = 37.84412065298033 (from 1 pairs)
# Δt = 496.0: Averaged MSD = 39.70825215308573 (from 1 pairs)
# Δt = 504.0: Averaged MSD = 39.69503796070986 (from 1 pairs)
# Δt = 508.0: Averaged MSD = 39.68913900853409 (from 1 pairs)
# Δt = 510.0: Averaged MSD = 39.68684729387202 (from 1 pairs)
# Δt = 511.0: Averaged MSD = 39.685930721940814 (from 1 pairs)
# Δt = 512.0: Averaged MSD = 40.56439970987032 (from 1 pairs)
# Δt = 768.0: Averaged MSD = 48.14008039976995 (from 1 pairs)
# Δt = 896.0: Averaged MSD = 50.52932277882123 (from 1 pairs)
# Δt = 960.0: Averaged MSD = 51.26944474867361 (from 1 pairs)
# Δt = 992.0: Averaged MSD = 51.007472554264005 (from 1 pairs)
# Δt = 1008.0: Averaged MSD = 51.83312577751332 (from 1 pairs)
# Δt = 1016.0: Averaged MSD = 51.82351295304266 (from 1 pairs)
# Δt = 1020.0: Averaged MSD = 51.81873009825116 (from 1 pairs)
# Δt = 1022.0: Averaged MSD = 51.816659110028965 (from 1 pairs)
# Δt = 1023.0: Averaged MSD = 51.81576843253431 (from 1 pairs)
# Δt = 1024.0: Averaged MSD = 52.38606454981948 (from 1 pairs)
# Δt = 1536.0: Averaged MSD = 59.65104685553488 (from 1 pairs)
# Δt = 1792.0: Averaged MSD = 62.41002681256982 (from 1 pairs)
# Δt = 1920.0: Averaged MSD = 63.23241846159734 (from 1 pairs)
# Δt = 1984.0: Averaged MSD = 64.32869887817648 (from 1 pairs)
# Δt = 2016.0: Averaged MSD = 64.08164145732026 (from 1 pairs)
# Δt = 2032.0: Averaged MSD = 64.31839593300761 (from 1 pairs)
# Δt = 2040.0: Averaged MSD = 64.30764576387135 (from 1 pairs)
# Δt = 2044.0: Averaged MSD = 64.30217066505429 (from 1 pairs)
# Δt = 2046.0: Averaged MSD = 64.29958717407878 (from 1 pairs)
# Δt = 2047.0: Averaged MSD = 64.29840190573968 (from 1 pairs)
# Δt = 2048.0: Averaged MSD = 63.26712361055931 (from 1 pairs)
# Δt = 3072.0: Averaged MSD = 73.00128102145455 (from 1 pairs)
# Δt = 3584.0: Averaged MSD = 75.84716223083744 (from 1 pairs)
# Δt = 3840.0: Averaged MSD = 78.77121042707579 (from 1 pairs)
# Δt = 3968.0: Averaged MSD = 77.58434323879888 (from 1 pairs)
# Δt = 4032.0: Averaged MSD = 79.70539809428068 (from 1 pairs)
# Δt = 4064.0: Averaged MSD = 79.61092595254237 (from 1 pairs)
# Δt = 4080.0: Averaged MSD = 79.09636476589019 (from 1 pairs)
# Δt = 4088.0: Averaged MSD = 79.0846188282073 (from 1 pairs)
# Δt = 4092.0: Averaged MSD = 79.0792116951201 (from 1 pairs)
# Δt = 4094.0: Averaged MSD = 79.07646287403166 (from 1 pairs)
# Δt = 4095.0: Averaged MSD = 79.07508475484535 (from 1 pairs)
# Δt = 4096.0: Averaged MSD = 80.34696654483196 (from 1 pairs)
# Δt = 6144.0: Averaged MSD = 89.59385945588288 (from 1 pairs)
# Δt = 7168.0: Averaged MSD = 92.4771755041678 (from 1 pairs)
# Δt = 7680.0: Averaged MSD = 94.50601482556266 (from 1 pairs)
# Δt = 7936.0: Averaged MSD = 95.30709943992346 (from 1 pairs)
# Δt = 8064.0: Averaged MSD = 94.83921412765278 (from 1 pairs)
# Δt = 8128.0: Averaged MSD = 96.46608153410426 (from 1 pairs)
# Δt = 8160.0: Averaged MSD = 96.07529507293124 (from 1 pairs)
# Δt = 8176.0: Averaged MSD = 95.0703795753964 (from 1 pairs)
# Δt = 8184.0: Averaged MSD = 95.06224977404133 (from 1 pairs)
# Δt = 8188.0: Averaged MSD = 95.0586318471605 (from 1 pairs)
# Δt = 8190.0: Averaged MSD = 95.05691656152716 (from 1 pairs)
# Δt = 8191.0: Averaged MSD = 95.0561195452338 (from 1 pairs)
# Δt = 8192.0: Averaged MSD = 95.6749269293592 (from 1 pairs)
# Δt = 12288.0: Averaged MSD = 105.98158715820061 (from 1 pairs)
# Δt = 14336.0: Averaged MSD = 113.11262024089335 (from 1 pairs)
# Δt = 15360.0: Averaged MSD = 114.86296624961577 (from 1 pairs)
# Δt = 15872.0: Averaged MSD = 115.14821465864308 (from 1 pairs)
# Δt = 16128.0: Averaged MSD = 115.01257625985546 (from 1 pairs)
# Δt = 16256.0: Averaged MSD = 115.09371358732456 (from 1 pairs)
# Δt = 16320.0: Averaged MSD = 116.07066118887714 (from 1 pairs)
# Δt = 16352.0: Averaged MSD = 116.1453616118024 (from 1 pairs)
# Δt = 16368.0: Averaged MSD = 115.85999522354626 (from 1 pairs)
# Δt = 16376.0: Averaged MSD = 115.85158365140158 (from 1 pairs)
# Δt = 16380.0: Averaged MSD = 115.84681872223021 (from 1 pairs)
# Δt = 16382.0: Averaged MSD = 115.8444636769963 (from 1 pairs)
# Δt = 16383.0: Averaged MSD = 115.84334776265332 (from 1 pairs)
# Δt = 16384.0: Averaged MSD = 117.8430379304564 (from 1 pairs)
# Δt = 24576.0: Averaged MSD = 129.93721799327494 (from 1 pairs)
# Δt = 28672.0: Averaged MSD = 134.89743167052117 (from 1 pairs)
# Δt = 30720.0: Averaged MSD = 138.38773938443575 (from 1 pairs)
# Δt = 31744.0: Averaged MSD = 139.81045174955855 (from 1 pairs)
# Δt = 32256.0: Averaged MSD = 139.72291876100206 (from 1 pairs)
# Δt = 32512.0: Averaged MSD = 139.36489490333685 (from 1 pairs)
# Δt = 32640.0: Averaged MSD = 138.77086026920705 (from 1 pairs)
# Δt = 32704.0: Averaged MSD = 139.53694210194084 (from 1 pairs)
# Δt = 32736.0: Averaged MSD = 139.32947865853333 (from 1 pairs)
# Δt = 32752.0: Averaged MSD = 138.81921029593568 (from 1 pairs)
# Δt = 32760.0: Averaged MSD = 138.8145400262058 (from 1 pairs)
# Δt = 32764.0: Averaged MSD = 138.81145265630792 (from 1 pairs)
# Δt = 32766.0: Averaged MSD = 138.80978457190727 (from 1 pairs)
# Δt = 32767.0: Averaged MSD = 138.8089833987945 (from 1 pairs)
# Δt = 32768.0: Averaged MSD = 137.51225615773905 (from 1 pairs)
# Δt = 49152.0: Averaged MSD = 155.38746564708995 (from 1 pairs)
# Δt = 57344.0: Averaged MSD = 161.02476755657787 (from 1 pairs)
# Δt = 61440.0: Averaged MSD = 162.86232261396907 (from 1 pairs)
# Δt = 63488.0: Averaged MSD = 165.07072758803668 (from 1 pairs)
# Δt = 64512.0: Averaged MSD = 165.53112568543196 (from 1 pairs)
# Δt = 65024.0: Averaged MSD = 166.40779313829609 (from 1 pairs)
# Δt = 65280.0: Averaged MSD = 165.89287294297677 (from 1 pairs)
# Δt = 65408.0: Averaged MSD = 164.9173708198413 (from 1 pairs)
# Δt = 65472.0: Averaged MSD = 165.43714775006828 (from 1 pairs)
# Δt = 65504.0: Averaged MSD = 165.24795441208641 (from 1 pairs)
# Δt = 65520.0: Averaged MSD = 165.2289176158489 (from 1 pairs)
# Δt = 65528.0: Averaged MSD = 165.21748180956425 (from 1 pairs)
# Δt = 65532.0: Averaged MSD = 165.21200440639748 (from 1 pairs)
# Δt = 65534.0: Averaged MSD = 165.209326059722 (from 1 pairs)
# Δt = 65535.0: Averaged MSD = 165.20803198843214 (from 1 pairs)
# Δt = 65536.0: Averaged MSD = 168.80832178652344 (from 1 pairs)
# Δt = 98304.0: Averaged MSD = 183.97142189827989 (from 1 pairs)
# Δt = 114688.0: Averaged MSD = 193.2254145017506 (from 1 pairs)
# Δt = 122880.0: Averaged MSD = 198.54156989911317 (from 1 pairs)
# Δt = 126976.0: Averaged MSD = 197.63991451714725 (from 1 pairs)
# Δt = 129024.0: Averaged MSD = 199.3592471401318 (from 1 pairs)
# Δt = 130048.0: Averaged MSD = 199.90542627942867 (from 1 pairs)
# Δt = 130560.0: Averaged MSD = 199.30600157051416 (from 1 pairs)
# Δt = 130816.0: Averaged MSD = 198.73485030986157 (from 1 pairs)
# Δt = 130944.0: Averaged MSD = 199.0693117863434 (from 1 pairs)
# Δt = 131008.0: Averaged MSD = 198.8720590139899 (from 1 pairs)
# Δt = 131040.0: Averaged MSD = 199.13948025737383 (from 1 pairs)
# Δt = 131056.0: Averaged MSD = 198.91094224850616 (from 1 pairs)
# Δt = 131064.0: Averaged MSD = 198.89847873007443 (from 1 pairs)
# Δt = 131068.0: Averaged MSD = 198.89208178986917 (from 1 pairs)
# Δt = 131070.0: Averaged MSD = 198.8891240609642 (from 1 pairs)
# Δt = 131071.0: Averaged MSD = 198.8877409309397 (from 1 pairs)
# Δt = 131072.0: Averaged MSD = 201.32125908729543 (from 1 pairs)
# Δt = 196608.0: Averaged MSD = 218.4323255825468 (from 1 pairs)
# Δt = 229376.0: Averaged MSD = 226.7747105158084 (from 1 pairs)
# Δt = 245760.0: Averaged MSD = 229.94474559114212 (from 1 pairs)
# Δt = 253952.0: Averaged MSD = 231.2420741989289 (from 1 pairs)
# Δt = 258048.0: Averaged MSD = 232.3515263573921 (from 1 pairs)
# Δt = 260096.0: Averaged MSD = 232.79747083334175 (from 1 pairs)
# Δt = 261120.0: Averaged MSD = 232.96060127768374 (from 1 pairs)
# Δt = 261632.0: Averaged MSD = 233.87615460649832 (from 1 pairs)
# Δt = 261888.0: Averaged MSD = 233.3005698337889 (from 1 pairs)
# Δt = 262016.0: Averaged MSD = 231.90319528303516 (from 1 pairs)
# Δt = 262080.0: Averaged MSD = 233.07300398776408 (from 1 pairs)
# Δt = 262112.0: Averaged MSD = 233.75737895526706 (from 1 pairs)
# Δt = 262128.0: Averaged MSD = 232.75702127523112 (from 1 pairs)
# Δt = 262136.0: Averaged MSD = 232.74432618900195 (from 1 pairs)
# Δt = 262140.0: Averaged MSD = 232.73874023244977 (from 1 pairs)
# Δt = 262142.0: Averaged MSD = 232.73598400765007 (from 1 pairs)
# Δt = 262143.0: Averaged MSD = 232.73461269452594 (from 1 pairs)
# Δt = 262144.0: Averaged MSD = 223.122891181001 (from 1 pairs)
# Δt = 393216.0: Averaged MSD = 246.4805273301529 (from 1 pairs)
# Δt = 458752.0: Averaged MSD = 255.56858502873234 (from 1 pairs)
# Δt = 491520.0: Averaged MSD = 262.5544693897263 (from 1 pairs)
# Δt = 507904.0: Averaged MSD = 264.27175242872784 (from 1 pairs)
# Δt = 516096.0: Averaged MSD = 265.6932551001765 (from 1 pairs)
# Δt = 520192.0: Averaged MSD = 268.03091387418624 (from 1 pairs)
# Δt = 522240.0: Averaged MSD = 269.2740580761632 (from 1 pairs)
# Δt = 523264.0: Averaged MSD = 268.4584451324952 (from 1 pairs)
# Δt = 523776.0: Averaged MSD = 269.21264350190233 (from 1 pairs)
# Δt = 524032.0: Averaged MSD = 269.28977223771636 (from 1 pairs)
# Δt = 524160.0: Averaged MSD = 269.4258243020933 (from 1 pairs)
# Δt = 524224.0: Averaged MSD = 269.3780992129194 (from 1 pairs)
# Δt = 524256.0: Averaged MSD = 269.2736712071331 (from 1 pairs)
# Δt = 524272.0: Averaged MSD = 269.01614463366377 (from 1 pairs)
# Δt = 524280.0: Averaged MSD = 269.0060177377771 (from 1 pairs)
# Δt = 524284.0: Averaged MSD = 269.0007189627239 (from 1 pairs)
# Δt = 524286.0: Averaged MSD = 268.99810322258725 (from 1 pairs)
# Δt = 524287.0: Averaged MSD = 268.9968443646768 (from 1 pairs)
# Δt = 524288.0: Averaged MSD = 284.66040133504475 (from 1 pairs)
# Δt = 786432.0: Averaged MSD = 313.8757395670679 (from 1 pairs)
# Δt = 917504.0: Averaged MSD = 322.03722349000816 (from 1 pairs)
# Δt = 983040.0: Averaged MSD = 333.1681416948045 (from 1 pairs)
# Δt = 1015808.0: Averaged MSD = 335.55669968262185 (from 1 pairs)
# Δt = 1032192.0: Averaged MSD = 331.4506261660773 (from 1 pairs)
# Δt = 1040384.0: Averaged MSD = 335.8494330432577 (from 1 pairs)
# Δt = 1044480.0: Averaged MSD = 336.21248820024647 (from 1 pairs)
# Δt = 1046528.0: Averaged MSD = 335.35646093685546 (from 1 pairs)
# Δt = 1047552.0: Averaged MSD = 335.9981535520451 (from 1 pairs)
# Δt = 1048064.0: Averaged MSD = 336.7204829382142 (from 1 pairs)
# Δt = 1048320.0: Averaged MSD = 335.9280763307999 (from 1 pairs)
# Δt = 1048448.0: Averaged MSD = 335.5723645288706 (from 1 pairs)
# Δt = 1048512.0: Averaged MSD = 335.9260630030505 (from 1 pairs)
# Δt = 1048544.0: Averaged MSD = 336.17442117706173 (from 1 pairs)
# Δt = 1048560.0: Averaged MSD = 335.8686088799973 (from 1 pairs)
# Δt = 1048568.0: Averaged MSD = 335.8551021107883 (from 1 pairs)
# Δt = 1048572.0: Averaged MSD = 335.84789135432186 (from 1 pairs)
# Δt = 1048574.0: Averaged MSD = 335.8444356330485 (from 1 pairs)
# Δt = 1048575.0: Averaged MSD = 335.84280119424255 (from 1 pairs)

# %% [markdown]
# #### 5) Block (4) code Should work for linearly dumped file as well! Let's switch our the .txt to the linear one and run the same code as of block (4)

# %%
import MDAnalysis as mda
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict


# Load universe
u = mda.Universe("production_1ns.dump", format="LAMMPSDUMP")

# Load actual times (shape: n_frames,)
times = np.loadtxt('python_linear.txt')
n_frames = len(times)

# Select all atoms
all_atoms = u.select_atoms("all")
n_atoms = len(all_atoms)

# Preload positions (shape: n_frames, n_atoms, 3)
positions = np.zeros((n_frames, n_atoms, 3))
for frame_idx, ts in enumerate(u.trajectory):
    positions[frame_idx] = all_atoms.positions

# Dictionary to collect MSDs: {Δt: [msd1, msd2, ...]}
msd_dict = defaultdict(list)

# Loop over all frame pairs (i < j)
for i in range(n_frames):
    for j in range(i + 1, n_frames):
        delta_t = times[j] - times[i]

        # Compute displacement and squared displacement
        disp = positions[j] - positions[i]  # shape (n_atoms, 3)
        squared_disp = np.sum(disp ** 2, axis=1)  # shape (n_atoms,)
        msd = np.mean(squared_disp)  # average over atoms

        # Store MSD under corresponding Δt
        msd_dict[delta_t].append(msd)

print(msd_dict)
msd_dict[0] = [0]
# Prepare averaged results
delta_t_values = []
avg_msds = []

for delta_t in sorted(msd_dict.keys()):
    msd_list = msd_dict[delta_t]
    avg_msd = np.mean(msd_list)
    delta_t_values.append(delta_t)
    avg_msds.append(avg_msd)
    print(f"Δt = {delta_t}: Averaged MSD = {avg_msd} (from {len(msd_list)} pairs)")

# Plot Δt vs averaged MSD
plt.figure(figsize=(8, 5))
plt.plot(delta_t_values, avg_msds, marker='o', linestyle='-', label='Averaged MSD')

plt.xlabel('Δt (Time Difference)')
plt.ylabel('Mean Squared Displacement (MSD)')
plt.title('MSD Averaged Over Frame Pairs with Same Δt')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# defaultdict(<class 'list'>, {1.0: [7.567643921399091e-05, 0.0003010483342465401, 0.0011812128882260973, 0.004357233602991862, 9.543333733783664, 8.909475600211127, 18.009000566625506, 22.78526855092501, 32.19839134443004, 40.56439970987032, 52.38606454981948, 63.26712361055931, 80.34696654483196, 95.6749269293592, 117.8430379304564, 137.51225615773905, 168.80832178652344, 201.32125908729543, 223.122891181001, 284.66040133504475], 2.0: [0.0006711921641563701, 0.0025656259044513716, 0.008751948518137457, 9.533641002612157, 15.17734442516213, 20.476540385422243, 28.63409883782932, 36.05976862016476, 48.14008039976995, 59.65104685553488, 73.00128102145455, 89.59385945588288, 105.98158715820061, 129.93721799327494, 155.38746564708995, 183.97142189827989, 218.4323255825468, 246.4805273301529, 313.8757395670679], 3.0: [0.0034164327871623753, 0.011181908940227003, 9.530578573399412, 15.164856714781138, 23.216520613257945, 29.73568260537573, 37.44200568194917, 50.52932277882123, 62.41002681256982, 75.84716223083744, 92.4771755041678, 113.11262024089335, 134.89743167052117, 161.02476755657787, 193.2254145017506, 226.7747105158084, 255.56858502873234, 322.03722349000816], 4.0: [0.012431675144152965, 9.529808290536062, 15.160428420627987, 23.205664242507694, 30.71894080045508, 37.84412065298033, 51.26944474867361, 63.23241846159734, 78.77121042707579, 94.50601482556266, 114.86296624961577, 138.38773938443575, 162.86232261396907, 198.54156989911317, 229.94474559114212, 262.5544693897263, 333.1681416948045], 5.0: [9.529627627822155, 15.158977168059968, 23.201359749806645, 30.70783284917266, 39.70825215308573, 51.007472554264005, 64.32869887817648, 77.58434323879888, 95.30709943992346, 115.14821465864308, 139.81045174955855, 165.07072758803668, 197.63991451714725, 231.2420741989289, 264.27175242872784, 335.55669968262185], 6.0: [15.158470625154514, 23.199660636605618, 30.70388223012308, 39.69503796070986, 51.83312577751332, 64.08164145732026, 79.70539809428068, 94.83921412765278, 115.01257625985546, 139.72291876100206, 165.53112568543196, 199.3592471401318, 232.3515263573921, 265.6932551001765, 331.4506261660773], 7.0: [23.198975843973113, 30.70256620998786, 39.68913900853409, 51.82351295304266, 64.31839593300761, 79.61092595254237, 96.46608153410426, 115.09371358732456, 139.36489490333685, 166.40779313829609, 199.90542627942867, 232.79747083334175, 268.03091387418624, 335.8494330432577], 8.0: [30.702104041633415, 39.68684729387202, 51.81873009825116, 64.30764576387135, 79.09636476589019, 96.07529507293124, 116.07066118887714, 138.77086026920705, 165.89287294297677, 199.30600157051416, 232.96060127768374, 269.2740580761632, 336.21248820024647], 9.0: [39.685930721940814, 51.816659110028965, 64.30217066505429, 79.0846188282073, 95.0703795753964, 116.1453616118024, 139.53694210194084, 164.9173708198413, 198.73485030986157, 233.87615460649832, 268.4584451324952, 335.35646093685546], 10.0: [51.81576843253431, 64.29958717407878, 79.0792116951201, 95.06224977404133, 115.85999522354626, 139.32947865853333, 165.43714775006828, 199.0693117863434, 233.3005698337889, 269.21264350190233, 335.9981535520451], 11.0: [64.29840190573968, 79.07646287403166, 95.0586318471605, 115.85158365140158, 138.81921029593568, 165.24795441208641, 198.8720590139899, 231.90319528303516, 269.28977223771636, 336.7204829382142], 12.0: [79.07508475484535, 95.05691656152716, 115.84681872223021, 138.8145400262058, 165.2289176158489, 199.13948025737383, 233.07300398776408, 269.4258243020933, 335.9280763307999], 13.0: [95.0561195452338, 115.8444636769963, 138.81145265630792, 165.21748180956425, 198.91094224850616, 233.75737895526706, 269.3780992129194, 335.5723645288706], 14.0: [115.84334776265332, 138.80978457190727, 165.21200440639748, 198.89847873007443, 232.75702127523112, 269.2736712071331, 335.9260630030505], 15.0: [138.8089833987945, 165.209326059722, 198.89208178986917, 232.74432618900195, 269.01614463366377, 336.17442117706173], 16.0: [165.20803198843214, 198.8891240609642, ...
# Δt = 0: Averaged MSD = 0.0 (from 1 pairs)
# Δt = 1.0: Averaged MSD = 77.84795168948702 (from 20 pairs)
# Δt = 2.0: Averaged MSD = 91.28136499721225 (from 19 pairs)
# Δt = 3.0: Averaged MSD = 100.16714904784327 (from 18 pairs)
# Δt = 4.0: Averaged MSD = 108.50426102164514 (from 17 pairs)
# Δt = 5.0: Averaged MSD = 115.95459365517338 (from 16 pairs)
# Δt = 6.0: Averaged MSD = 123.2225137586285 (from 15 pairs)
# Δt = 7.0: Averaged MSD = 131.66137450674026 (from 14 pairs)
# Δt = 8.0: Averaged MSD = 140.01342542785522 (from 13 pairs)
# Δt = 9.0: Averaged MSD = 148.91544536832689 (from 12 pairs)
# Δt = 10.0: Averaged MSD = 158.9512833983638 (from 11 pairs)
# Δt = 11.0: Averaged MSD = 169.51377544593112 (from 10 pairs)
# Δt = 12.0: Averaged MSD = 181.28762917318764 (from 9 pairs)
# Δt = 13.0: Averaged MSD = 194.0685378292082 (from 8 pairs)
# Δt = 14.0: Averaged MSD = 208.1029101366353 (from 7 pairs)
# Δt = 15.0: Averaged MSD = 223.4742138746855 (from 6 pairs)
# Δt = 16.0: Averaged MSD = 240.34210457992407 (from 5 pairs)
# Δt = 17.0: Averaged MSD = 259.1198865030255 (from 4 pairs)
# Δt = 18.0: Averaged MSD = 279.193535757145 (from 3 pairs)
# Δt = 19.0: Averaged MSD = 302.4206399988626 (from 2 pairs)
# Δt = 20.0: Averaged MSD = 335.84280119424255 (from 1 pairs)

# %% [markdown]
# #### The output of Block (5) is exactly same as Block (2) and (3)

# %% [markdown]
# #### Thus we conclude, Block 4 or 5 is the most generalized version of the code that calculate time averaged MSD and can be used in any dump format wheather it is linear and non-linear!
